# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

import json
from pprint import pprint


# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 609

# %% [markdown]
# ## Perform API Calls

# %%
# OpenWeatherMap API Key
api_key = api_keys.api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?appid=" + api_key + "&units=Imperial"  

response_json = []

for city in cities:
    response = requests.get(url +"&q="+ city).json()
    response_json.append(response)

pprint(response_json)
# Out:
# [{'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 39.62, 'lon': -77.74},
#   'dt': 1532408100,
#   'id': 4372777,
#   'main': {'humidity': 88,
#            'pressure': 1017,
#            'temp': 73.4,
#            'temp_max': 77,
#            'temp_min': 69.8},
#   'name': 'Vardo',
#   'sys': {'country': 'US',
#           'id': 1333,
#           'message': 0.0044,
#           'sunrise': 1532426602,
#           'sunset': 1532478666,
#           'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'fog', 'icon': '50n', 'id': 741, 'main': 'Fog'},
#               {'description': 'light rain',
#                'icon': '10n',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 140, 'speed': 8.05}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 73.51, 'lon': 80.55},
#   'dt': 1532409977,
#   'id': 1507390,
#   'main': {'grnd_level': 1022.53,
#            'humidity': 96,
#            'pressure': 1022.53,
#            'sea_level': 1022.91,
#            'temp': 45.89,
#            'temp_max': 45.89,
#            'temp_min': 45.89},
#   'name': 'Dikson',
#   'rain': {'3h': 16.33},
#   'sys': {'country': 'RU', 'message': 0.0043, 'sunrise': 0, 'sunset': 0},
#   'weather': [{'description': 'heavy intensity rain',
#                'icon': '10d',
#                'id': 502,
#                'main': 'Rain'}],
#   'wind': {'deg': 184.508, 'speed': 34.72}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 61.92, 'lon': 159.24},
#   'dt': 1532409703,
#   'id': 2125693,
#   'main': {'grnd_level': 1019.45,
#            'humidity': 87,
#            'pressure': 1019.45,
#            'sea_level': 1027.57,
#            'temp': 57.5,
#            'temp_max': 57.5,
#            'temp_min': 57.5},
#   'name': 'Evensk',
#   'sys': {'country': 'RU',
#           'message': 0.0049,
#           'sunrise': 1532363264,
#           'sunset': 1532428168},
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 223.508, 'speed': 3.74}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': -21.21, 'lon': -159.78},
#   'dt': 1532408400,
#   'id': 4035715,
#   'main': {'humidity': 88,
#            'pressure': 1014,
#            'temp': 71.6,
#            'temp_max': 71.6,
#            'temp_min': 71.6},
#   'name': 'Avarua',
#   'sys': {'country': 'CK',
#           'id': 8340,
#           'message': 0.003,
#           'sunrise': 1532452428,
#           'sunset': 1532492261,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03n',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 80, 'speed': 4.7}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 41.96, 'lon': 42.96},
#   'dt': 1532406600,
#   'id': 610864,
#   'main': {'humidity': 83,
#            'pressure': 1004,
#            'temp': 75.2,
#            'temp_max': 75.2,
#            'temp_min': 75.2},
#   'name': 'Khani',
#   'sys': {'country': 'GE',
#           'id': 7218,
#           'message': 0.0039,
#           'sunrise': 1532397231,
#           'sunset': 1532450097,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 90, 'speed': 5.82}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 22.08, 'lon': -159.32},
#   'dt': 1532408160,
#   'id': 5848280,
#   'main': {'humidity': 88,
#            'pressure': 1016,
#            'temp': 80.6,
#            'temp_max': 80.6,
#            'temp_min': 80.6},
#   'name': 'Kapaa',
#   'sys': {'country': 'US',
#           'id': 833,
#           'message': 0.0039,
#           'sunrise': 1532448389,
#           'sunset': 1532496055,
#           'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 70, 'speed': 11.41}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -22.28, 'lon': 166.46},
#   'dt': 1532408400,
#   'id': 2139521,
#   'main': {'humidity': 56,
#            'pressure': 1015,
#            'temp': 71.6,
#            'temp_max': 71.6,
#            'temp_min': 71.6},
#   'name': 'Noumea',
#   'sys': {'country': 'NC',
#           'id': 8344,
#           'message': 0.0036,
#           'sunrise': 1532374256,
#           'sunset': 1532413835,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 140, 'speed': 8.05}},
#  {'base': 'stations',
#   'clouds': {'all': 8},
#   'cod': 200,
#   'coord': {'lat': 59.7, 'lon': 30.79},
#   'dt': 1532406600,
#   'id': 546105,
#   'main': {'humidity': 88,
#            'pressure': 1015,
#            'temp': 68,
#            'temp_max': 68,
#            'temp_min': 68},
#   'name': 'Nikolskoye',
#   'sys': {'country': 'RU',
#           'id': 7267,
#           'message': 0.0037,
#           'sunrise': 1532395296,
#           'sunset': 1532457814,
#           'type': 1},
#   'visibility': 9000,
#   'weather': [{'description': 'clear sky',
#                'icon': '02d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 100, 'speed': 4.47}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': 20.89, 'lon': -156.47},
#   'dt': 1532408160,
#   'id': 5847411,
#   'main': {'humidity': 69,
#            'pressure': 1014,
#            'temp': 80.08,
#            'temp_max': 82.4,
#            'temp_min': 75.2},
#   'name': 'Kahului',
#   'sys': {'country': 'US',
#           'id': 823,
#           'message': 0.0034,
#           'sunrise': 1532447827,
#           'sunset': 1532495250,
#           'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03n',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 60, 'gust': 9.3, 'speed': 16.11}},
#  {'base': 'stations',
#   'clouds': {'all': 80},
#   'cod': 200,
#   'coord': {'lat': -5.01, 'lon': -63},
#   'dt': 1532410014,
#   'id': 3665361,
#   'main': {'grnd_level': 1021.23,
#            'humidity': 79,
#            'pressure': 1021.23,
#            'sea_level': 1026.11,
#            'temp': 80.18,
#            'temp_max': 80.18,
#            'temp_min': 80.18},
#   'name': 'Turiacu',
#   'sys': {'country': 'BR',
#           'message': 0.0038,
#           'sunrise': 1532427732,
#           'sunset': 1532470494},
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 60.0082, 'speed': 2.62}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 70.47, 'lon': -68.59},
#   'dt': 1532408400,
#   'id': 5924351,
#   'main': {'humidity': 80,
#            'pressure': 1006,
#            'temp': 35.6,
#            'temp_max': 35.6,
#            'temp_min': 35.6},
#   'name': 'Clyde River',
#   'sys': {'country': 'CA',
#           'id': 3585,
#           'message': 0.0035,
#           'sunrise': 0,
#           'sunset': 0,
#           'type': 1},
#   'visibility': 14484,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 320, 'gust': 19.5, 'speed': 31.09}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 39.31, 'lon': -74.98},
#   'dt': 1532409120,
#   'id': 4501427,
#   'main': {'humidity': 88,
#            'pressure': 1020,
#            'temp': 76.64,
#            'temp_max': 78.8,
#            'temp_min': 75.2},
#   'name': 'Port Elizabeth',
#   'sys': {'country': 'US',
#           'id': 1971,
#           'message': 0.0086,
#           'sunrise': 1532425988,
#           'sunset': 1532477955,
#           'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'light rain',
#                'icon': '10n',
#                'id': 500,
#                'main': 'Rain'},
#               {'description': 'mist',
#                'icon': '50n',
#                'id': 701,
#                'main': 'Mist'}],
#   'wind': {'deg': 140, 'gust': 8.7, 'speed': 13.87}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': -29.95, 'lon': -71.34},
#   'dt': 1532404800,
#   'id': 3893629,
#   'main': {'humidity': 93,
#            'pressure': 1018,
#            'temp': 46.4,
#            'temp_max': 46.4,
#            'temp_min': 46.4},
#   'name': 'Coquimbo',
#   'sys': {'country': 'CL',
#           'id': 4666,
#           'message': 0.0042,
#           'sunrise': 1532432131,
#           'sunset': 1532470110,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 80, 'speed': 4.7}},
#  {'base': 'stations',
#   'clouds': {'all': 92},
#   'cod': 200,
#   'coord': {'lat': 10.57, 'lon': 72.64},
#   'dt': 1532409941,
#   'id': 1267390,
#   'main': {'grnd_level': 1023.75,
#            'humidity': 99,
#            'pressure': 1023.75,
#            'sea_level': 1023.8,
#            'temp': 81.53,
#            'temp_max': 81.53,
#            'temp_min': 81.53},
#   'name': 'Kavaratti',
#   'rain': {'3h': 0.28},
#   'sys': {'country': 'IN',
#           'message': 0.0268,
#           'sunrise': 1532393813,
#           'sunset': 1532439296},
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 272.008, 'speed': 20.85}},
#  {'base': 'stations',
#   'clouds': {'all': 92},
#   'cod': 200,
#   'coord': {'lat': 37.16, 'lon': 122.42},
#   'dt': 1532410015,
#   'id': 1786855,
#   'main': {'grnd_level': 1013.29,
#            'humidity': 86,
#            'pressure': 1013.29,
#            'sea_level': 1017.68,
#            'temp': 82.25,
#            'temp_max': 82.25,
#            'temp_min': 82.25},
#   'name': 'Rongcheng',
#   'rain': {'3h': 0.14},
#   'sys': {'country': 'CN',
#           'message': 0.008,
#           'sunrise': 1532378911,
#           'sunset': 1532430283},
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 148.508, 'speed': 16.49}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 62.57, 'lon': 11.38},
#   'dt': 1532407800,
#   'id': 3141332,
#   'main': {'humidity': 93,
#            'pressure': 1012,
#            'temp': 55.4,
#            'temp_max': 55.4,
#            'temp_min': 55.4},
#   'name': 'Roros',
#   'sys': {'country': 'NO',
#           'id': 5323,
#           'message': 0.0126,
#           'sunrise': 1532398426,
#           'sunset': 1532463972,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'speed': 2.24}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -42.88, 'lon': 147.33},
#   'dt': 1532408400,
#   'id': 2163355,
#   'main': {'humidity': 62,
#            'pressure': 992,
#            'temp': 53.6,
#            'temp_max': 53.6,
#            'temp_min': 53.6},
#   'name': 'Hobart',
#   'sys': {'country': 'AU',
#           'id': 8195,
#           'message': 0.004,
#           'sunrise': 1532381436,
#           'sunset': 1532415849,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 360, 'speed': 14.99}},
#  {'base': 'stations',
#   'clouds': {'all': 88},
#   'cod': 200,
#   'coord': {'lat': -14.56, 'lon': 40.69},
#   'dt': 1532410016,
#   'id': 1035025,
#   'main': {'grnd_level': 1033.64,
#            'humidity': 95,
#            'pressure': 1033.64,
#            'sea_level': 1035.55,
#            'temp': 74.51,
#            'temp_max': 74.51,
#            'temp_min': 74.51},
#   'name': 'Nacala',
#   'sys': {'country': 'MZ',
#           'message': 0.0029,
#           'sunrise': 1532403695,
#           'sunset': 1532444763},
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 171.508, 'speed': 3.62}},
#  {'base': 'stations',
#   'clouds': {'all': 44},
#   'cod': 200,
#   'coord': {'lat': 18.93, 'lon': 84.6},
#   'dt': 1532410016,
#   'id': 1255816,
#   'main': {'grnd_level': 994.65,
#            'humidity': 82,
#            'pressure': 994.65,
#            'sea_level': 1015.57,
#            'temp': 85.58,
#            'temp_max': 85.58,
#            'temp_min': 85.58},
#   'name': 'Sompeta',
#   'sys': {'country': 'IN',
#           'message': 0.0029,
#           'sunrise': 1532390151,
#           'sunset': 1532437212},
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03d',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 250.008, 'speed': 7.43}},
#  {'base': 'stations',
#   'clouds': {'all': 36},
#   'cod': 200,
#   'coord': {'lat': -34.53, 'lon': 20.04},
#   'dt': 1532408400,
#   'id': 1015776,
#   'main': {'humidity': 87,
#            'pressure': 1021,
#            'temp': 46.4,
#            'temp_max': 46.4,
#            'temp_min': 46.4},
#   'name': 'Bredasdorp',
#   'sys': {'country': 'ZA',
#           'id': 6591,
#           'message': 0.0033,
#           'sunrise': 1532410762,
#           'sunset': 1532447619,
#           'type': 1},
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03n',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 290, 'speed': 4.7}},
#  {'base': 'stations',
#   'clouds': {'all': 56},
#   'cod': 200,
#   'coord': {'lat': 3.07, 'lon': 172.79},
#   'dt': 1532409905,
#   'id': 2110227,
#   'main': {'grnd_level': 1021.4,
#            'humidity': 100,
#            'pressure': 1021.4,
#            'sea_level': 1021.37,
#            'temp': 83.87,
#            'temp_max': 83.87,
#            'temp_min': 83.87},
#   'name': 'Butaritari',
#   'sys': {'country': 'KI',
#           'message': 0.0034,
#           'sunrise': 1532370441,
#           'sunset': 1532414600},
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 132.508, 'speed': 7.43}},
#  {'base': 'stations',
#   'clouds': {'all': 92},
#   'cod': 200,
#   'coord': {'lat': -9.8, 'lon': -139.03},
#   'dt': 1532409912,
#   'id': 4020109,
#   'main': {'grnd_level': 1026.18,
#            'humidity': 100,
#            'pressure': 1026.18,
#            'sea_level': 1026.19,
#            'temp': 79.73,
#            'temp_max': 79.73,
#            'temp_min': 79.73},
#   'name': 'Atuona',
#   'sys': {'country': 'PF',
#           'message': 0.0031,
#           'sunrise': 1532446395,
#           'sunset': 1532488327},
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 86.0082, 'speed': 20.74}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 23.66, 'lon': 90.19},
#   'dt': 1532408400,
#   'id': 1185100,
#   'main': {'humidity': 74,
#            'pressure': 1002,
#            'temp': 87.8,
#            'temp_max': 87.8,
#            'temp_min': 87.8},
#   'name': 'Nawabganj',
#   'sys': {'country': 'BD',
#           'id': 7879,
#           'message': 0.0041,
#           'sunrise': 1532388323,
#           'sunset': 1532436354,
#           'type': 1},
#   'visibility': 4000,
#   'weather': [{'description': 'haze',
#                'icon': '50d',
#                'id': 721,
#                'main': 'Haze'}],
#   'wind': {'deg': 140, 'speed': 9.17}},
#  {'base': 'stations',
#   'clouds': {'all': 12},
#   'cod': 200,
#   'coord': {'lat': 70.62, 'lon': 147.9},
#   'dt': 1532409907,
#   'id': 2126123,
#   'main': {'grnd_level': 1021.48,
#            'humidity': 73,
#            'pressure': 1021.48,
#            'sea_level': 1023.55,
#            'temp': 51.02,
#            'temp_max': 51.02,
#            'temp_min': 51.02},
#   'name': 'Chokurdakh',
#   'sys': {'country': 'RU', 'message': 0.004, 'sunrise': 0, 'sunset': 0},
#   'weather': [{'description': 'few clouds',
#                'icon': '02d',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 286.508, 'speed': 17.49}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 55.74, 'lon': -97.86},
#   'dt': 1532408400,
#   'id': 6165406,
#   'main': {'humidity': 100,
#            'pressure': 1009,
#            'temp': 59,
#            'temp_max': 59,
#            'temp_min': 59},
#   'name': 'Thompson',
#   'sys': {'country': 'CA',
#           'id': 3406,
#           'message': 0.0029,
#           'sunrise': 1532427781,
#           'sunset': 1532487104,
#           'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'light intensity shower rain',
#                'icon': '09n',
#                'id': 520,
#                'main': 'Rain'}],
#   'wind': {'deg': 30, 'gust': 8.7, 'speed': 12.75}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 62.93, 'lon': 152.39},
#   'dt': 1532410018,
#   'id': 2121373,
#   'main': {'grnd_level': 974.22,
#            'humidity': 41,
#            'pressure': 974.22,
#            'sea_level': 1020.15,
#            'temp': 75.5,
#            'temp_max': 75.5,
#            'temp_min': 75.5},
#   'name': 'Seymchan',
#   'sys': {'country': 'RU',
#           'message': 0.0031,
#           'sunrise': 1532364289,
#           'sunset': 1532430418},
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 235.008, 'speed': 4.63}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 65.4, 'lon': 64.7},
#   'dt': 1532410018,
#   'id': 1498161,
#   'main': {'grnd_level': 1026.02,
#            'humidity': 46,
#            'pressure': 1026.02,
#            'sea_level': 1030.93,
#            'temp': 82.79,
#            'temp_max': 82.79,
#            'temp_min': 82.79},
#   'name': 'Muzhi',
#   'sys': {'country': 'RU',
#           'message': 0.0033,
#           'sunrise': 1532383469,
#           'sunset': 1532453278},
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 299.508, 'speed': 10.67}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 40.21, 'lon': 140.05},
#   'dt': 1532404800,
#   'id': 2128867,
#   'main': {'humidity': 70,
#            'pressure': 1007,
#            'temp': 83.12,
#            'temp_max': 84.2,
#            'temp_min': 82.4},
#   'name': 'Noshiro',
#   'sys': {'country': 'JP',
#           'id': 7601,
#           'message': 0.0033,
#           'sunrise': 1532374207,
#           'sunset': 1532426520,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 290, 'speed': 10.29}},
#  {'base': 'stations',
#   'clouds': {'all': 92},
#   'cod': 200,
#   'coord': {'lat': -3.36, 'lon': 135.5},
#   'dt': 1532410019,
#   'id': 1634614,
#   'main': {'grnd_level': 948.04,
#            'humidity': 92,
#            'pressure': 948.04,
#            'sea_level': 1023.6,
#            'temp': 72.17,
#            'temp_max': 72.17,
#            'temp_min': 72.17},
#   'name': 'Nabire',
#   'rain': {'3h': 1.31},
#   'sys': {'country': 'ID',
#           'message': 0.0034,
#           'sunrise': 1532379950,
#           'sunset': 1532422994},
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 61.0082, 'speed': 2.17}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 21.05, 'lon': -89.07},
#   'dt': 1532407680,
#   'id': 3526662,
#   'main': {'humidity': 78,
#            'pressure': 1016,
#            'temp': 82.4,
#            'temp_max': 82.4,
#            'temp_min': 82.4},
#   'name': 'Teya',
#   'sys': {'country': 'MX',
#           'id': 3996,
#           'message': 0.0032,
#           'sunrise': 1532431630,
#           'sunset': 1532479094,
#           'type': 1},
#   'visibility': 11265,
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 110, 'speed': 6.93}},
#  {'base': 'stations',
#   'clouds': {'all': 92},
#   'cod': 200,
#   'coord': {'lat': 15.34, 'lon': 74.49},
#   'dt': 1532409910,
#   'id': 1273574,
#   'main': {'grnd_level': 956.39,
#            'humidity': 98,
#            'pressure': 956.39,
#            'sea_level': 1021.12,
#            'temp': 72.89,
#            'temp_max': 72.89,
#            'temp_min': 72.89},
#   'name': 'Vaini',
#   'rain': {'3h': 1.475},
#   'sys': {'country': 'IN',
#           'message': 0.0029,
#           'sunrise': 1532392927,
#           'sunset': 1532439292},
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 252.508, 'speed': 7.65}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 77.48, 'lon': -69.36},
#   'dt': 1532409942,
#   'id': 3831208,
#   'main': {'grnd_level': 988.17,
#            'humidity': 100,
#            'pressure': 988.17,
#            'sea_level': 1019.91,
#            'temp': 33.02,
#            'temp_max': 33.02,
#            'temp_min': 33.02},
#   'name': 'Qaanaaq',
#   'sys': {'country': 'GL', 'message': 0.0104, 'sunrise': 0, 'sunset': 0},
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 324.008, 'speed': 3.85}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -20.63, 'lon': -46},
#   'dt': 1532409926,
#   'id': 3453439,
#   'main': {'grnd_level': 932.96,
#            'humidity': 82,
#            'pressure': 932.96,
#            'sea_level': 1035.67,
#            'temp': 47.69,
#            'temp_max': 47.69,
#            'temp_min': 47.69},
#   'name': 'Ponta do Sol',
#   'sys': {'country': 'BR',
#           'message': 0.003,
#           'sunrise': 1532425070,
#           'sunset': 1532465003},
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 63.5082, 'speed': 2.17}},
#  {'base': 'stations',
#   'clouds': {'all': 48},
#   'cod': 200,
#   'coord': {'lat': -23.12, 'lon': -134.97},
#   'dt': 1532409938,
#   'id': 4030556,
#   'main': {'grnd_level': 1033.15,
#            'humidity': 99,
#            'pressure': 1033.15,
#            'sea_level': 1033.28,
#            'temp': 74.6,
#            'temp_max': 74.6,
#            'temp_min': 74.6},
#   'name': 'Rikitea',
#   'sys': {'country': 'PF',
#           'message': 0.003,
#           'sunrise': 1532446665,
#           'sunset': 1532486115},
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03n',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 53.0082, 'speed': 14.47}},
#  {'base': 'stations',
#   'clouds': {'all': 32},
#   'cod': 200,
#   'coord': {'lat': -46.13, 'lon': 167.69},
#   'dt': 1532409960,
#   'id': 2180815,
#   'main': {'grnd_level': 1005.76,
#            'humidity': 100,
#            'pressure': 1005.76,
#            'sea_level': 1031.66,
#            'temp': 42.56,
#            'temp_max': 42.56,
#            'temp_min': 42.56},
#   'name': 'Tuatapere',
#   'sys': {'country': 'NZ',
#           'message': 0.0038,
#           'sunrise': 1532377125,
#           'sunset': 1532410390},
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03d',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 61.5082, 'speed': 9.22}},
#  {'base': 'stations',
#   'clouds': {'all': 88},
#   'cod': 200,
#   'coord': {'lat': -33.64, 'lon': 115.35},
#   'dt': 1532409687,
#   'id': 2075265,
#   'main': {'grnd_level': 1026.34,
#            'humidity': 98,
#            'pressure': 1026.34,
#            'sea_level': 1027.36,
#            'temp': 63.71,
#            'temp_max': 63.71,
#            'temp_min': 63.71},
#   'name': 'Busselton',
#   'sys': {'country': 'AU',
#           'message': 0.0039,
#           'sunrise': 1532387785,
#           'sunset': 1532424846},
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 300.008, 'speed': 13.24}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 53.05, 'lon': 158.65},
#   'dt': 1532406600,
#   'id': 2122104,
#   'main': {'humidity': 87,
#            'pressure': 1017,
#            'temp': 59,
#            'temp_max': 59,
#            'temp_min': 59},
#   'name': 'Petropavlovsk-Kamchatskiy',
#   'sys': {'country': 'RU',
#           'id': 7248,
#           'message': 0.0037,
#           'sunrise': 1532366993,
#           'sunset': 1532424778,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 150, 'speed': 6.71}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 38.73, 'lon': -27.07},
#   'dt': 1532408400,
#   'id': 3372760,
#   'main': {'humidity': 100,
#            'pressure': 1022,
#            'temp': 68,
#            'temp_max': 68,
#            'temp_min': 68},
#   'name': 'Praia da Vitoria',
#   'sys': {'country': 'PT',
#           'id': 5951,
#           'message': 0.0137,
#           'sunrise': 1532414572,
#           'sunset': 1532466375,
#           'type': 1},
#   'visibility': 7000,
#   'weather': [{'description': 'light rain',
#                'icon': '10n',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 357.008, 'speed': 16.15}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -38.31, 'lon': -60.23},
#   'dt': 1532409978,
#   'id': 3833859,
#   'main': {'grnd_level': 1034.77,
#            'humidity': 63,
#            'pressure': 1034.77,
#            'sea_level': 1047.79,
#            'temp': 30.68,
#            'temp_max': 30.68,
#            'temp_min': 30.68},
#   'name': 'Barrow',
#   'sys': {'country': 'AR',
#           'message': 0.0044,
#           'sunrise': 1532430524,
#           'sunset': 1532466389},
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 333.008, 'speed': 10.11}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 37.17, 'lon': -99.65},
#   'dt': 1532409951,
#   'id': 4267710,
#   'main': {'grnd_level': 960.36,
#            'humidity': 55,
#            'pressure': 960.36,
#            'sea_level': 1032.19,
#            'temp': 78.02,
#            'temp_max': 78.02,
#            'temp_min': 78.02},
#   'name': 'Sitka',
#   'sys': {'country': 'US',
#           'message': 0.004,
#           'sunrise': 1532432235,
#           'sunset': 1532483553},
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 45.5082, 'speed': 8.66}},
#  {'base': 'stations',
#   'clouds': {'all': 12},
#   'cod': 200,
#   'coord': {'lat': 61.07, 'lon': 42.1},
#   'dt': 1532410021,
#   'id': 475938,
#   'main': {'grnd_level': 1018.56,
#            'humidity': 63,
#            'pressure': 1018.56,
#            'sea_level': 1033.73,
#            'temp': 73.52,
#            'temp_max': 73.52,
#            'temp_min': 73.52},
#   'name': 'Velsk',
#   'sys': {'country': 'RU',
#           'message': 0.0035,
#           'sunrise': 1532391898,
#           'sunset': 1532455770},
#   'weather': [{'description': 'few clouds',
#                'icon': '02d',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 169.508, 'speed': 6.64}},
#  {'base': 'stations',
#   'clouds': {'all': 76},
#   'cod': 200,
#   'coord': {'lat': -54.81, 'lon': -68.31},
#   'dt': 1532409651,
#   'id': 3833367,
#   'main': {'grnd_level': 963.77,
#            'humidity': 91,
#            'pressure': 963.77,
#            'sea_level': 1008.77,
#            'temp': 40.22,
#            'temp_max': 40.22,
#            'temp_min': 40.22},
#   'name': 'Ushuaia',
#   'rain': {'3h': 0.285},
#   'sys': {'country': 'AR',
#           'message': 0.0038,
#           'sunrise': 1532435711,
#           'sunset': 1532465093},
#   'weather': [{'description': 'light rain',
#                'icon': '10n',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 297.508, 'speed': 19.51}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -27.15, 'lon': -48.54},
#   'dt': 1532408400,
#   'id': 3452900,
#   'main': {'humidity': 77,
#            'pressure': 1025,
#            'temp': 60.8,
#            'temp_max': 60.8,
#            'temp_min': 60.8},
#   'name': 'Porto Belo',
#   'sys': {'country': 'BR',
#           'id': 4493,
#           'message': 0.0095,
#           'sunrise': 1532426349,
#           'sunset': 1532464946,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 180, 'speed': 10.29}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 27.18, 'lon': 31.19},
#   'dt': 1532404800,
#   'id': 359783,
#   'main': {'humidity': 69,
#            'pressure': 1008,
#            'temp': 78.8,
#            'temp_max': 78.8,
#            'temp_min': 78.8},
#   'name': 'Asyut',
#   'sys': {'country': 'EG',
#           'id': 6387,
#           'message': 0.0041,
#           'sunrise': 1532402099,
#           'sunset': 1532450895,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 340, 'speed': 11.41}},
#  {'base': 'stations',
#   'clouds': {'all': 12},
#   'cod': 200,
#   'coord': {'lat': 14.1, 'lon': -1.63},
#   'dt': 1532410022,
#   'id': 2361177,
#   'main': {'grnd_level': 989.3,
#            'humidity': 78,
#            'pressure': 989.3,
#            'sea_level': 1022.46,
#            'temp': 78.47,
#            'temp_max': 78.47,
#            'temp_min': 78.47},
#   'name': 'Djibo',
#   'sys': {'country': 'BF',
#           'message': 0.0149,
#           'sunrise': 1532411316,
#           'sunset': 1532457441},
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 230.508, 'speed': 8.66}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 69.49, 'lon': 88.39},
#   'dt': 1532409960,
#   'id': 1490256,
#   'main': {'grnd_level': 1007.46,
#            'humidity': 61,
#            'pressure': 1007.46,
#            'sea_level': 1028.01,
#            'temp': 54.62,
#            'temp_max': 54.62,
#            'temp_min': 54.62},
#   'name': 'Talnakh',
#   'sys': {'country': 'RU', 'message': 0.0033, 'sunrise': 0, 'sunset': 0},
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 34.0082, 'speed': 9.78}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 48.45, 'lon': 0.83},
#   'dt': 1532408400,
#   'id': 2991703,
#   'main': {'humidity': 82,
#            'pressure': 1014,
#            'temp': 65.32,
#            'temp_max': 66.2,
#            'temp_min': 64.4},
#   'name': 'Ronne',
#   'sys': {'country': 'FR',
#           'id': 5598,
#           'message': 0.0037,
#           'sunrise': 1532406077,
#           'sunset': 1532461461,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'speed': 4.7}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': -26.98, 'lon': -56.83},
#   'dt': 1532409663,
#   'id': 3437029,
#   'main': {'grnd_level': 1028.94,
#            'humidity': 91,
#            'pressure': 1028.94,
#            'sea_level': 1039.56,
#            'temp': 51.92,
#            'temp_max': 51.92,
#            'temp_min': 51.92},
#   'name': 'San Patricio',
#   'rain': {'3h': 0.67},
#   'sys': {'country': 'PY',
#           'message': 0.004,
#           'sunrise': 1532428320,
#           'sunset': 1532466955},
#   'weather': [{'description': 'light rain',
#                'icon': '10n',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 153.508, 'speed': 6.53}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 54.23, 'lon': 85.8},
#   'dt': 1532410024,
#   'id': 1493224,
#   'main': {'grnd_level': 973.49,
#            'humidity': 69,
#            'pressure': 973.49,
#            'sea_level': 1016.38,
#            'temp': 63.44,
#            'temp_max': 63.44,
#            'temp_min': 63.44},
#   'name': 'Salair',
#   'sys': {'country': 'RU',
#           'message': 0.0052,
#           'sunrise': 1532384142,
#           'sunset': 1532442592},
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 242.508, 'speed': 5.19}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 38.94, 'lon': 100.46},
#   'dt': 1532409671,
#   'id': 1785036,
#   'main': {'grnd_level': 824.02,
#            'humidity': 60,
#            'pressure': 824.02,
#            'sea_level': 1011.72,
#            'temp': 84.14,
#            'temp_max': 84.14,
#            'temp_min': 84.14},
#   'name': 'Zhangye',
#   'sys': {'country': 'CN',
#           'message': 0.0048,
#           'sunrise': 1532383915,
#           'sunset': 1532435817},
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 116.008, 'speed': 6.76}},
#  {'base': 'stations',
#   'clouds': {'all': 8},
#   'cod': 200,
#   'coord': {'lat': 50.36, 'lon': 108.75},
#   'dt': 1532410024,
#   'id': 2012349,
#   'main': {'grnd_level': 898.43,
#            'humidity': 64,
#            'pressure': 898.43,
#            'sea_level': 1016.58,
#            'temp': 75.59,
#            'temp_max': 75.59,
#            'temp_min': 75.59},
#   'name': 'Krasnyy Chikoy',
#   'sys': {'country': 'RU',
#           'message': 0.0032,
#           'sunrise': 1532379701,
#           'sunset': 1532436030},
#   'weather': [{'description': 'clear sky',
#                'icon': '02d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 240.508, 'speed': 3.06}},
#  {'base': 'stations',
#   'clouds': {'all': 92},
#   'cod': 200,
#   'coord': {'lat': 9.68, 'lon': 6.4},
#   'dt': 1532410024,
#   'id': 2330100,
#   'main': {'grnd_level': 993.92,
#            'humidity': 100,
#            'pressure': 993.92,
#            'sea_level': 1026.35,
#            'temp': 70.19,
#            'temp_max': 70.19,
#            'temp_min': 70.19},
#   'name': 'Bako',
#   'rain': {'3h': 29.42},
#   'sys': {'country': 'NG',
#           'message': 0.0036,
#           'sunrise': 1532409793,
#           'sunset': 1532455112},
#   'weather': [{'description': 'heavy intensity rain',
#                'icon': '10d',
#                'id': 502,
#                'main': 'Rain'}],
#   'wind': {'deg': 123.008, 'speed': 5.3}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 63.75, 'lon': -68.52},
#   'dt': 1532408400,
#   'id': 5983720,
#   'main': {'humidity': 60,
#            'pressure': 1017,
#            'temp': 39.2,
#            'temp_max': 39.2,
#            'temp_min': 39.2},
#   'name': 'Iqaluit',
#   'sys': {'country': 'CA',
#           'id': 3590,
#           'message': 0.0035,
#           'sunrise': 1532416855,
#           'sunset': 1532483877,
#           'type': 1},
#   'visibility': 32186,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 320, 'gust': 17.5, 'speed': 29.97}},
#  {'base': 'stations',
#   'clouds': {'all': 8},
#   'cod': 200,
#   'coord': {'lat': -46.19, 'lon': 168.86},
#   'dt': 1532409930,
#   'id': 6201424,
#   'main': {'grnd_level': 1016.78,
#            'humidity': 83,
#            'pressure': 1016.78,
#            'sea_level': 1032.43,
#            'temp': 40.76,
#            'temp_max': 40.76,
#            'temp_min': 40.76},
#   'name': 'Mataura',
#   'sys': {'country': 'NZ',
#           'message': 0.0035,
#           'sunrise': 1532376855,
#           'sunset': 1532410098},
#   'weather': [{'description': 'clear sky',
#                'icon': '02d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 88.0082, 'speed': 10}},
#  {'base': 'stations',
#   'clouds': {'all': 24},
#   'cod': 200,
#   'coord': {'lat': -2.68, 'lon': 111.62},
#   'dt': 1532409692,
#   'id': 1632694,
#   'main': {'grnd_level': 1010.7,
#            'humidity': 62,
#            'pressure': 1010.7,
#            'sea_level': 1021.77,
#            'temp': 90.08,
#            'temp_max': 90.08,
#            'temp_min': 90.08},
#   'name': 'Pangkalanbuun',
#   'sys': {'country': 'ID',
#           'message': 0.0032,
#           'sunrise': 1532385622,
#           'sunset': 1532428784},
#   'weather': [{'description': 'few clouds',
#                'icon': '02d',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 119.508, 'speed': 8.55}},
#  {'base': 'stations',
#   'clouds': {'all': 76},
#   'cod': 200,
#   'coord': {'lat': 67.46, 'lon': 153.71},
#   'dt': 1532410025,
#   'id': 2121025,
#   'main': {'grnd_level': 1010.86,
#            'humidity': 66,
#            'pressure': 1010.86,
#            'sea_level': 1020.72,
#            'temp': 69.74,
#            'temp_max': 69.74,
#            'temp_min': 69.74},
#   'name': 'Srednekolymsk',
#   'sys': {'country': 'RU',
#           'message': 0.0037,
#           'sunrise': 1532359625,
#           'sunset': 1532434288},
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 341.008, 'speed': 6.31}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': -23.7, 'lon': 133.88},
#   'dt': 1532408400,
#   'id': 2077895,
#   'main': {'humidity': 22,
#            'pressure': 1016,
#            'temp': 77,
#            'temp_max': 77,
#            'temp_min': 77},
#   'name': 'Alice Springs',
#   'sys': {'country': 'AU',
#           'id': 8163,
#           'message': 0.0031,
#           'sunrise': 1532382218,
#           'sunset': 1532421513,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 160, 'speed': 4.7}},
#  {'base': 'stations',
#   'clouds': {'all': 5},
#   'cod': 200,
#   'coord': {'lat': 22.89, 'lon': -109.91},
#   'dt': 1532407260,
#   'id': 3985710,
#   'main': {'humidity': 55,
#            'pressure': 1012,
#            'temp': 85.62,
#            'temp_max': 87.8,
#            'temp_min': 84.2},
#   'name': 'Cabo San Lucas',
#   'sys': {'country': 'MX',
#           'id': 4015,
#           'message': 0.0031,
#           'sunrise': 1532436443,
#           'sunset': 1532484283,
#           'type': 1},
#   'visibility': 19312,
#   'weather': [{'description': 'clear sky',
#                'icon': '02n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 286.008, 'speed': 11.45}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 5.35, 'lon': 48.53},
#   'dt': 1532409952,
#   'id': 57000,
#   'main': {'grnd_level': 1019.37,
#            'humidity': 67,
#            'pressure': 1019.37,
#            'sea_level': 1028.74,
#            'temp': 79.55,
#            'temp_max': 79.55,
#            'temp_min': 79.55},
#   'name': 'Hobyo',
#   'sys': {'country': 'SO',
#           'message': 0.0111,
#           'sunrise': 1532400065,
#           'sunset': 1532444620},
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 228.508, 'speed': 20.74}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 45.36, 'lon': -73.48},
#   'dt': 1532408640,
#   'id': 6138908,
#   'main': {'humidity': 83,
#            'pressure': 1020,
#            'temp': 76.55,
#            'temp_max': 77,
#            'temp_min': 75.2},
#   'name': 'Saint-Philippe',
#   'sys': {'country': 'CA',
#           'id': 3851,
#           'message': 0.0056,
#           'sunrise': 1532424573,
#           'sunset': 1532478640,
#           'type': 1},
#   'visibility': 14484,
#   'weather': [{'description': 'light intensity shower rain',
#                'icon': '09n',
#                'id': 520,
#                'main': 'Rain'}],
#   'wind': {'deg': 180, 'gust': 11.3, 'speed': 16.11}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': 62.45, 'lon': -114.38},
#   'dt': 1532408400,
#   'id': 6185377,
#   'main': {'humidity': 76,
#            'pressure': 1026,
#            'temp': 55.4,
#            'temp_max': 55.4,
#            'temp_min': 55.4},
#   'name': 'Yellowknife',
#   'sys': {'country': 'CA',
#           'id': 3558,
#           'message': 0.0037,
#           'sunrise': 1532428738,
#           'sunset': 1532494026,
#           'type': 1},
#   'visibility': 24140,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03n',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 190, 'speed': 6.93}},
#  {'base': 'stations',
#   'clouds': {'all': 92},
#   'cod': 200,
#   'coord': {'lat': 72.79, 'lon': -56.15},
#   'dt': 1532409981,
#   'id': 3418910,
#   'main': {'grnd_level': 1011.27,
#            'humidity': 92,
#            'pressure': 1011.27,
#            'sea_level': 1014.35,
#            'temp': 39.95,
#            'temp_max': 39.95,
#            'temp_min': 39.95},
#   'name': 'Upernavik',
#   'sys': {'country': 'GL', 'message': 0.004, 'sunrise': 0, 'sunset': 0},
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 351.508, 'speed': 8.66}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 42.65, 'lon': -73.75},
#   'dt': 1532408940,
#   'id': 5106834,
#   'main': {'humidity': 78,
#            'pressure': 1022,
#            'temp': 74.3,
#            'temp_max': 75.2,
#            'temp_min': 73.4},
#   'name': 'Albany',
#   'sys': {'country': 'US',
#           'id': 2088,
#           'message': 0.0039,
#           'sunrise': 1532425140,
#           'sunset': 1532478208,
#           'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 150, 'speed': 6.93}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 34.64, 'lon': -120.46},
#   'dt': 1532408580,
#   'id': 5367788,
#   'main': {'humidity': 87,
#            'pressure': 1016,
#            'temp': 59.34,
#            'temp_max': 60.8,
#            'temp_min': 57.2},
#   'name': 'Lompoc',
#   'sys': {'country': 'US',
#           'id': 410,
#           'message': 0.0037,
#           'sunrise': 1532437587,
#           'sunset': 1532488192,
#           'type': 1},
#   'visibility': 14484,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 290, 'speed': 10.29}},
#  {'base': 'stations',
#   'clouds': {'all': 1},
#   'cod': 200,
#   'coord': {'lat': 47.5, 'lon': -111.29},
#   'dt': 1532408280,
#   'id': 5655240,
#   'main': {'humidity': 34,
#            'pressure': 1020,
#            'temp': 68.92,
#            'temp_max': 69.8,
#            'temp_min': 68},
#   'name': 'Great Falls',
#   'sys': {'country': 'US',
#           'id': 1741,
#           'message': 0.0053,
#           'sunrise': 1532433217,
#           'sunset': 1532488141,
#           'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 9.50818, 'speed': 2.95}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 43.35, 'lon': 3.22},
#   'dt': 1532408400,
#   'id': 3032833,
#   'main': {'humidity': 68,
#            'pressure': 1012,
#            'temp': 66.97,
#            'temp_max': 68,
#            'temp_min': 66.2},
#   'name': 'Beziers',
#   'sys': {'country': 'FR',
#           'id': 5589,
#           'message': 0.0043,
#           'sunrise': 1532406530,
#           'sunset': 1532459871,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 20, 'speed': 4.7}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': 60.79, 'lon': -161.76},
#   'dt': 1532407980,
#   'id': 5880568,
#   'main': {'humidity': 67,
#            'pressure': 1014,
#            'temp': 62.6,
#            'temp_max': 62.6,
#            'temp_min': 62.6},
#   'name': 'Bethel',
#   'sys': {'country': 'US',
#           'id': 28,
#           'message': 0.0035,
#           'sunrise': 1532441051,
#           'sunset': 1532504474,
#           'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03n',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 100, 'speed': 11.41}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -42.78, 'lon': 147.06},
#   'dt': 1532408400,
#   'id': 2155415,
#   'main': {'humidity': 62,
#            'pressure': 992,
#            'temp': 53.6,
#            'temp_max': 53.6,
#            'temp_min': 53.6},
#   'name': 'New Norfolk',
#   'sys': {'country': 'AU',
#           'id': 8195,
#           'message': 0.0047,
#           'sunrise': 1532381485,
#           'sunset': 1532415931,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 360, 'speed': 14.99}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 40.67, 'lon': 33.6},
#   'dt': 1532410028,
#   'id': 749747,
#   'main': {'grnd_level': 873.71,
#            'humidity': 45,
#            'pressure': 873.71,
#            'sea_level': 1015.33,
#            'temp': 75.41,
#            'temp_max': 75.41,
#            'temp_min': 75.41},
#   'name': 'Ayan',
#   'sys': {'country': 'TR',
#           'message': 0.004,
#           'sunrise': 1532399695,
#           'sunset': 1532452127},
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 154.008, 'speed': 3.06}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 18.45, 'lon': -72.29},
#   'dt': 1532410028,
#   'id': 3723440,
#   'main': {'grnd_level': 960.93,
#            'humidity': 100,
#            'pressure': 960.93,
#            'sea_level': 1030.2,
#            'temp': 66.59,
#            'temp_max': 66.59,
#            'temp_min': 66.59},
#   'name': 'Kenscoff',
#   'sys': {'country': 'HT',
#           'message': 0.0067,
#           'sunrise': 1532427862,
#           'sunset': 1532474810},
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 113.008, 'speed': 2.95}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -6.34, 'lon': -47.4},
#   'dt': 1532410029,
#   'id': 3391371,
#   'main': {'grnd_level': 1004.54,
#            'humidity': 48,
#            'pressure': 1004.54,
#            'sea_level': 1026.35,
#            'temp': 74.42,
#            'temp_max': 74.42,
#            'temp_min': 74.42},
#   'name': 'Porto Franco',
#   'sys': {'country': 'BR',
#           'message': 0.0057,
#           'sunrise': 1532424103,
#           'sunset': 1532466635},
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
# ...
#            'temp_min': 93.2},
#   'name': 'Buraydah',
#   'sys': {'country': 'SA',
#           'id': 6984,
#           'message': 0.004,
#           'sunrise': 1532399127,
#           'sunset': 1532447733,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 320, 'speed': 9.17}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 10.35, 'lon': 107.08},
#   'dt': 1532406600,
#   'id': 1562414,
#   'main': {'humidity': 66,
#            'pressure': 1007,
#            'temp': 91.4,
#            'temp_max': 91.4,
#            'temp_min': 91.4},
#   'name': 'Vung Tau',
#   'sys': {'country': 'VN',
#           'id': 7985,
#           'message': 0.0036,
#           'sunrise': 1532385566,
#           'sunset': 1532431012,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 260, 'speed': 16.11}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -20.01, 'lon': 57.66},
#   'dt': 1532408400,
#   'id': 934479,
#   'main': {'humidity': 57,
#            'pressure': 1025,
#            'temp': 75.2,
#            'temp_max': 75.2,
#            'temp_min': 75.2},
#   'name': 'Grand Gaube',
#   'sys': {'country': 'MU',
#           'id': 6729,
#           'message': 0.0034,
#           'sunrise': 1532400137,
#           'sunset': 1532440178,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'shower rain',
#                'icon': '09d',
#                'id': 521,
#                'main': 'Rain'}],
#   'wind': {'deg': 110, 'speed': 21.92}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 52.6, 'lon': 15.9},
#   'dt': 1532408400,
#   'id': 3091983,
#   'main': {'humidity': 77,
#            'pressure': 1016,
#            'temp': 66.2,
#            'temp_max': 66.2,
#            'temp_min': 66.2},
#   'name': 'Miedzychod',
#   'sys': {'country': 'PL',
#           'id': 5376,
#           'message': 0.0036,
#           'sunrise': 1532401416,
#           'sunset': 1532458876,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 350, 'speed': 4.7}},
#  {'base': 'stations',
#   'clouds': {'all': 56},
#   'cod': 200,
#   'coord': {'lat': 6.5, 'lon': 17.45},
#   'dt': 1532410159,
#   'id': 2388036,
#   'main': {'grnd_level': 966.52,
#            'humidity': 93,
#            'pressure': 966.52,
#            'sea_level': 1025.38,
#            'temp': 72.35,
#            'temp_max': 72.35,
#            'temp_min': 72.35},
#   'name': 'Bossangoa',
#   'sys': {'country': 'CF',
#           'message': 0.0031,
#           'sunrise': 1532407424,
#           'sunset': 1532452179},
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 222.508, 'speed': 10.56}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 23.63, 'lon': 94.42},
#   'dt': 1532410160,
#   'id': 1310120,
#   'main': {'grnd_level': 974.79,
#            'humidity': 100,
#            'pressure': 974.79,
#            'sea_level': 1017.6,
#            'temp': 74.69,
#            'temp_max': 74.69,
#            'temp_min': 74.69},
#   'name': 'Mawlaik',
#   'rain': {'3h': 1.85},
#   'sys': {'country': 'MM',
#           'message': 0.0028,
#           'sunrise': 1532387311,
#           'sunset': 1532435336},
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 152.508, 'speed': 2.73}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 52.19, 'lon': 9.08},
#   'dt': 1532407800,
#   'id': 2846523,
#   'main': {'humidity': 77,
#            'pressure': 1016,
#            'temp': 61.65,
#            'temp_max': 64.4,
#            'temp_min': 60.8},
#   'name': 'Rinteln',
#   'sys': {'country': 'DE',
#           'id': 4893,
#           'message': 0.0063,
#           'sunrise': 1532403168,
#           'sunset': 1532460399,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 70, 'speed': 3.36}},
#  {'base': 'stations',
#   'clouds': {'all': 64},
#   'cod': 200,
#   'coord': {'lat': 50.71, 'lon': -1.5},
#   'dt': 1532407800,
#   'id': 2633414,
#   'main': {'humidity': 93,
#            'pressure': 1015,
#            'temp': 57.25,
#            'temp_max': 59,
#            'temp_min': 53.6},
#   'name': 'Yarmouth',
#   'sys': {'country': 'GB',
#           'id': 5082,
#           'message': 0.0038,
#           'sunrise': 1532406098,
#           'sunset': 1532462552,
#           'type': 1},
#   'visibility': 9000,
#   'weather': [{'description': 'fog', 'icon': '50d', 'id': 741, 'main': 'Fog'},
#               {'description': 'mist', 'icon': '50d', 'id': 701, 'main': 'Mist'},
#               {'description': 'haze',
#                'icon': '50d',
#                'id': 721,
#                'main': 'Haze'}],
#   'wind': {'deg': 322.508, 'speed': 3.74}},
#  {'base': 'stations',
#   'clouds': {'all': 8},
#   'cod': 200,
#   'coord': {'lat': 54.81, 'lon': 105.15},
#   'dt': 1532410161,
#   'id': 2012532,
#   'main': {'grnd_level': 933.86,
#            'humidity': 60,
#            'pressure': 933.86,
#            'sea_level': 1014.07,
#            'temp': 76.22,
#            'temp_max': 76.22,
#            'temp_min': 76.22},
#   'name': 'Zhigalovo',
#   'sys': {'country': 'RU',
#           'message': 0.0041,
#           'sunrise': 1532379310,
#           'sunset': 1532438134},
#   'weather': [{'description': 'clear sky',
#                'icon': '02d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 151.008, 'speed': 4.63}},
#  {'base': 'stations',
#   'clouds': {'all': 68},
#   'cod': 200,
#   'coord': {'lat': 50.72, 'lon': 136.64},
#   'dt': 1532410161,
#   'id': 2016307,
#   'main': {'grnd_level': 998.87,
#            'humidity': 72,
#            'pressure': 998.87,
#            'sea_level': 1018.53,
#            'temp': 78.56,
#            'temp_max': 78.56,
#            'temp_min': 78.56},
#   'name': 'Solnechnyy',
#   'sys': {'country': 'RU',
#           'message': 0.0037,
#           'sunrise': 1532372911,
#           'sunset': 1532429431},
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 43.5082, 'speed': 3.62}},
#  {'base': 'stations',
#   'clouds': {'all': 92},
#   'cod': 200,
#   'coord': {'lat': 8.94, 'lon': -11.9},
#   'dt': 1532410161,
#   'id': 2406407,
#   'main': {'grnd_level': 1010.7,
#            'humidity': 98,
#            'pressure': 1010.7,
#            'sea_level': 1027.93,
#            'temp': 72.89,
#            'temp_max': 72.89,
#            'temp_min': 72.89},
#   'name': 'Mabama',
#   'rain': {'3h': 0.26},
#   'sys': {'country': 'SL',
#           'message': 0.0031,
#           'sunrise': 1532414252,
#           'sunset': 1532459438},
#   'weather': [{'description': 'light rain',
#                'icon': '10n',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 256.508, 'speed': 4.85}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 29.3, 'lon': 113.14},
#   'dt': 1532410161,
#   'id': 1927639,
#   'main': {'grnd_level': 1001.14,
#            'humidity': 62,
#            'pressure': 1001.14,
#            'sea_level': 1014.31,
#            'temp': 96.02,
#            'temp_max': 96.02,
#            'temp_min': 96.02},
#   'name': 'Guozhen',
#   'sys': {'country': 'CN',
#           'message': 0.0032,
#           'sunrise': 1532382177,
#           'sunset': 1532431479},
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 179.508, 'speed': 4.07}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 50.03, 'lon': -66.88},
#   'dt': 1532408400,
#   'id': 6111696,
#   'main': {'humidity': 100,
#            'pressure': 1024,
#            'temp': 60.8,
#            'temp_max': 60.8,
#            'temp_min': 60.8},
#   'name': 'Port-Cartier',
#   'sys': {'country': 'CA',
#           'id': 3855,
#           'message': 0.0032,
#           'sunrise': 1532421972,
#           'sunset': 1532478063,
#           'type': 1},
#   'visibility': 8047,
#   'weather': [{'description': 'mist',
#                'icon': '50n',
#                'id': 701,
#                'main': 'Mist'}],
#   'wind': {'deg': 50, 'speed': 4.7}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -32.72, 'lon': 152.14},
#   'dt': 1532408400,
#   'id': 2155562,
#   'main': {'humidity': 17,
#            'pressure': 1011,
#            'temp': 75.2,
#            'temp_max': 75.2,
#            'temp_min': 75.2},
#   'name': 'Nelson Bay',
#   'sys': {'country': 'AU',
#           'id': 8242,
#           'message': 0.0031,
#           'sunrise': 1532378845,
#           'sunset': 1532416126,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 300, 'speed': 18.34}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 49.49, 'lon': -117.29},
#   'dt': 1532404800,
#   'id': 6086871,
#   'main': {'humidity': 31,
#            'pressure': 1017,
#            'temp': 78.8,
#            'temp_max': 78.8,
#            'temp_min': 78.8},
#   'name': 'Nelson',
#   'sys': {'country': 'CA',
#           'id': 3258,
#           'message': 0.007,
#           'sunrise': 1532434211,
#           'sunset': 1532490023,
#           'type': 1},
#   'visibility': 24140,
#   'weather': [{'description': 'shower rain',
#                'icon': '09n',
#                'id': 521,
#                'main': 'Rain'}],
#   'wind': {'speed': 9.17}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 41.28, 'lon': -70.1},
#   'dt': 1532409300,
#   'id': 4944903,
#   'main': {'humidity': 100,
#            'pressure': 1027,
#            'temp': 69.1,
#            'temp_max': 73.4,
#            'temp_min': 64.4},
#   'name': 'Nantucket',
#   'sys': {'country': 'US',
#           'id': 1287,
#           'message': 0.0121,
#           'sunrise': 1532424498,
#           'sunset': 1532477100,
#           'type': 1},
#   'visibility': 8047,
#   'weather': [{'description': 'mist',
#                'icon': '50n',
#                'id': 701,
#                'main': 'Mist'}],
#   'wind': {'deg': 130, 'speed': 10.29}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 32.52, 'lon': -93.73},
#   'dt': 1532409300,
#   'id': 4317639,
#   'main': {'humidity': 54,
#            'pressure': 1014,
#            'temp': 83.86,
#            'temp_max': 86,
#            'temp_min': 80.6},
#   'name': 'Bossier City',
#   'sys': {'country': 'US',
#           'id': 1163,
#           'message': 0.004,
#           'sunrise': 1532431448,
#           'sunset': 1532481503,
#           'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 110, 'speed': 4.7}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -30.3, 'lon': 153.13},
#   'dt': 1532406600,
#   'id': 2171085,
#   'main': {'humidity': 37,
#            'pressure': 1014,
#            'temp': 71.6,
#            'temp_max': 71.6,
#            'temp_min': 71.6},
#   'name': 'Coffs Harbour',
#   'sys': {'country': 'AU',
#           'id': 8179,
#           'message': 0.0038,
#           'sunrise': 1532378319,
#           'sunset': 1532416176,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 40, 'speed': 10.29}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 27.87, 'lon': -0.29},
#   'dt': 1532408400,
#   'id': 2508813,
#   'main': {'humidity': 12,
#            'pressure': 1008,
#            'temp': 87.8,
#            'temp_max': 87.8,
#            'temp_min': 87.8},
#   'name': 'Adrar',
#   'sys': {'country': 'DZ',
#           'id': 6220,
#           'message': 0.0037,
#           'sunrise': 1532409578,
#           'sunset': 1532458526,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 70, 'speed': 11.41}},
#  {'base': 'stations',
#   'clouds': {'all': 5},
#   'cod': 200,
#   'coord': {'lat': 22.3, 'lon': -101.57},
#   'dt': 1532407620,
#   'id': 3992485,
#   'main': {'humidity': 32,
#            'pressure': 1026,
#            'temp': 68,
#            'temp_max': 68,
#            'temp_min': 68},
#   'name': 'Pinos',
#   'sys': {'country': 'MX',
#           'id': 4017,
#           'message': 0.003,
#           'sunrise': 1532434502,
#           'sunset': 1532482221,
#           'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'clear sky',
#                'icon': '02n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 90, 'speed': 8.05}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 51.9, 'lon': 21.61},
#   'dt': 1532408400,
#   'id': 772339,
#   'main': {'humidity': 64,
#            'pressure': 1013,
#            'temp': 69.8,
#            'temp_max': 69.8,
#            'temp_min': 69.8},
#   'name': 'Garwolin',
#   'sys': {'country': 'PL',
#           'id': 5374,
#           'message': 0.0031,
#           'sunrise': 1532400237,
#           'sunset': 1532457317,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 340, 'speed': 9.17}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 60.72, 'lon': -135.06},
#   'dt': 1532408400,
#   'id': 6180550,
#   'main': {'humidity': 23,
#            'pressure': 1020,
#            'temp': 75.2,
#            'temp_max': 75.2,
#            'temp_min': 75.2},
#   'name': 'Whitehorse',
#   'sys': {'country': 'CA',
#           'id': 3963,
#           'message': 0.0038,
#           'sunrise': 1532434668,
#           'sunset': 1532498041,
#           'type': 1},
#   'visibility': 64372,
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 130, 'speed': 10.29}},
#  {'base': 'stations',
#   'clouds': {'all': 88},
#   'cod': 200,
#   'coord': {'lat': 8.5, 'lon': 8.51},
#   'dt': 1532410164,
#   'id': 2332515,
#   'main': {'grnd_level': 988.98,
#            'humidity': 99,
#            'pressure': 988.98,
#            'sea_level': 1026.23,
#            'temp': 71.72,
#            'temp_max': 71.72,
#            'temp_min': 71.72},
#   'name': 'Lafia',
#   'rain': {'3h': 0.225},
#   'sys': {'country': 'NG',
#           'message': 0.0033,
#           'sunrise': 1532409392,
#           'sunset': 1532454501},
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 232.508, 'speed': 5.75}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -13.65, 'lon': -73.37},
#   'dt': 1532409919,
#   'id': 3929607,
#   'main': {'grnd_level': 674.06,
#            'humidity': 81,
#            'pressure': 674.06,
#            'sea_level': 1031.54,
#            'temp': 24.65,
#            'temp_max': 24.65,
#            'temp_min': 24.65},
#   'name': 'San Jeronimo',
#   'sys': {'country': 'PE',
#           'message': 0.0097,
#           'sunrise': 1532430983,
#           'sunset': 1532472225},
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 351.008, 'speed': 1.61}}]

# %%
# OpenWeatherMap API Key
api_key = api_keys.api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?appid=" + api_key + "&units=Imperial"  

response_json = []
city_name = []
cloudiness = []
country =[]
date =[]
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []



for city in cities:
    response = requests.get(url +"&q="+ city).json()
    if response['cod']==200: 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])

city_dict = {"City": city_name,
             "Cloudiness": cloudiness,
             "Country": country,
             "Date": date,
             "Humidity": humidity,
             "Lat": lat,
             "lng": lng,
             "Max Temp": max_temp,
             "Wind Speed": wind_speed}

city_data = pd.DataFrame(city_dict)

Info = city_data.info()
Info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 554 entries, 0 to 553
# Data columns (total 9 columns):
# City          554 non-null object
# Cloudiness    554 non-null int64
# Country       554 non-null object
# Date          554 non-null int64
# Humidity      554 non-null int64
# Lat           554 non-null float64
# lng           554 non-null float64
# Max Temp      554 non-null float64
# Wind Speed    554 non-null float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 39.0+ KB

# %%
city_data.head()
# Out:
#      City  Cloudiness Country        Date  Humidity    Lat     lng  Max Temp  \
# 0   Vardo          20      US  1532408100        88  39.62  -77.74     77.00
# 1  Dikson         100      RU  1532409977        96  73.51   80.55     45.89
# 2  Evensk           0      RU  1532409703        87  61.92  159.24     57.50
# 3  Avarua          40      CK  1532408400        88 -21.21 -159.78     71.60
# 4   Khani           0      GE  1532406600        83  41.96   42.96     75.20
#
#    Wind Speed
# 0        8.05
# 1       34.72
# 2        3.74
# 3        4.70
# 4        5.82

# %%
plt.scatter(city_data["Lat"], city_data["Max Temp"], marker="o", facecolor="blue", edgecolors="black", 
            s=city_data["Lat"], alpha=0.75)

plt.title("City Latitude vs. Max Twmperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)

plt.savefig("../Images/Scatter plot for Lat vs max temp")
plt.show()
# Out:
# C:\Users\Tammy\Anaconda3\lib\site-packages\matplotlib\collections.py:902: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
plt.scatter(city_data["Lat"], city_data["Humidity"], marker="o", facecolor="blue", edgecolors="black", 
            s=city_data["Lat"], alpha=0.75)

plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

plt.savefig("../Images/Scatter plot for Lat vs Humidity")
plt.show()
# Out:
# C:\Users\Tammy\Anaconda3\lib\site-packages\matplotlib\collections.py:902: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
plt.scatter(city_data["Lat"], city_data["Cloudiness"], marker="o", facecolor="blue", edgecolors="black", 
            s=city_data["Lat"], alpha=0.75)

plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

plt.savefig("../Images/Scatter plot for Lat vs Cloudiness")
plt.show()
# Out:
# C:\Users\Tammy\Anaconda3\lib\site-packages\matplotlib\collections.py:902: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
plt.scatter(city_data["Lat"], city_data["Wind Speed"], marker="o", facecolor="blue", edgecolors="black", 
            s=city_data["Lat"], alpha=0.75)

plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

plt.savefig("../Images/Scatter plot for Lat vs Wind Speed")
plt.show()
# Out:
# C:\Users\Tammy\Anaconda3\lib\site-packages\matplotlib\collections.py:902: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
